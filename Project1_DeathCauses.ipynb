# %%
#Import Necessary Packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
#Load the Data into Pandas Dataframe

# %%
death = pd.read_csv("../Practice/Monthly_Counts_of_Deaths_by_Select_Causes__2014-2019.csv")
death
# Out:
#    Jurisdiction of Occurrence  Year  Month  All Cause  Natural Cause  \
# 0               United States  2014      1     243298         226621
# 1               United States  2015      1     265355         247269
# 2               United States  2016      1     245823         227341
# 3               United States  2017      1     262832         241918
# 4               United States  2018      1     286744         265418
# ..                        ...   ...    ...        ...            ...
# 67              United States  2015     12     233735         215657
# 68              United States  2016     12     249207         228888
# 69              United States  2017     12     258657         237819
# 70              United States  2018     12     249280         229184
# 71              United States  2019     12     255975         234438
#
#     Septicemia  Malignant Neoplasms  Diabetes Mellitus  Alzheimer Disease  \
# ...

# %%
#The first 5 rows of the dataframe

death.head(5)
# Out:
#   Jurisdiction of Occurrence  Year  Month  All Cause  Natural Cause  \
# 0              United States  2014      1     243298         226621
# 1              United States  2015      1     265355         247269
# 2              United States  2016      1     245823         227341
# 3              United States  2017      1     262832         241918
# 4              United States  2018      1     286744         265418
#
#    Septicemia  Malignant Neoplasms  Diabetes Mellitus  Alzheimer Disease  \
# 0        3944                51101               7344               8305
# 1        4194                52346               8053              11638
# 2        3846                51863               7392              10612
# 3        4089                52120               7907              12018
# 4        4502                52876               8674              13410
#
#    Influenza and Pneumonia  ...  Other Diseases of Respiratory System  \
# ...

# %%
#Data Cleaning

death.shape #Rows and Columns
# Out:
# (72, 21)

# %%
death.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 21 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   Jurisdiction of Occurrence                                                                72 non-null     object
#  1   Year                                                                                      72 non-null     int64
#  2   Month                                                                                     72 non-null     int64
#  3   All Cause                                                                                 72 non-null     int64
#  4   Natural Cause                                                                             72 non-null     int64
# ...

# %%
death.columns #What columns data have
# Out:
# Index(['Jurisdiction of Occurrence', 'Year', 'Month', 'All Cause',
#        'Natural Cause', 'Septicemia', 'Malignant Neoplasms',
#        'Diabetes Mellitus', 'Alzheimer Disease', 'Influenza and Pneumonia',
#        'Chronic Lower Respiratory Diseases',
#        'Other Diseases of Respiratory System',
#        'Nephritis, Nephrotic Syndrome, and Nephrosis',
#        'Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified',
#        'Diseases of Heart', 'Cerebrovascular Diseases',
#        'Accidents (Unintentional Injuries)', 'Motor Vehicle Accidents',
#        'Intentional Self-Harm (Suicide)', 'Assault (Homicide)',
#        'Drug Overdose'],
#       dtype='object')

# %%
death.dtypes #Type of each columns
# Out:
# Jurisdiction of Occurrence                                                                  object
# Year                                                                                         int64
# Month                                                                                        int64
# All Cause                                                                                    int64
# Natural Cause                                                                                int64
# Septicemia                                                                                   int64
# Malignant Neoplasms                                                                          int64
# Diabetes Mellitus                                                                            int64
# Alzheimer Disease                                                                            int64
# ...

# %%
#Check data for duplicate rows
death.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 67    False
# 68    False
# 69    False
# 70    False
# 71    False
# Length: 72, dtype: bool

# %%
death.duplicated().value_counts()
# Out:
# False    72
# dtype: int64

# %%
death['Jurisdiction of Occurrence'] = death['Jurisdiction of Occurrence'].astype('category')

death.dtypes
# Out:
# Jurisdiction of Occurrence                                                                  category
# Year                                                                                           int64
# Month                                                                                          int64
# All Cause                                                                                      int64
# Natural Cause                                                                                  int64
# Septicemia                                                                                     int64
# Malignant Neoplasms                                                                            int64
# Diabetes Mellitus                                                                              int64
# Alzheimer Disease                                                                              int64
# ...

# %%
#Exploratory Data Analysis(EDA)

death.dtypes
# Out:
# Jurisdiction of Occurrence                                                                  category
# Year                                                                                           int64
# Month                                                                                          int64
# All Cause                                                                                      int64
# Natural Cause                                                                                  int64
# Septicemia                                                                                     int64
# Malignant Neoplasms                                                                            int64
# Diabetes Mellitus                                                                              int64
# Alzheimer Disease                                                                              int64
# ...

# %%
#Check the distint values in columns
print("Drug Overdose =",death['Drug Overdose'].unique())
# Out:
# Drug Overdose = [4026 4354 4631 6233 5659 5519 3895 4087 5022 5619 5244 5180 4106 4583
#  5511 6164 5793 5887 3733 4281 5259 5886 5555 5562 3925 4462 5158 6036
#  5773 5829 3783 4176 5128 5884 5817 5807 3902 4497 5592 5938 5940 6162
#  3987 4492 5397 5863 5836 6194 3748 4481 5195 5786 5500 5882 4021 4546
#  5446 5538 5522 6133 3927 4199 5464 5491 5177 6176 4002 4246 5799 5551
#  6299]

# %%
death.skew()
# Out:
# Year                                                                                        0.000000
# Month                                                                                       0.000000
# All Cause                                                                                   0.993511
# Natural Cause                                                                               1.050066
# Septicemia                                                                                  1.144259
# Malignant Neoplasms                                                                        -0.472460
# Diabetes Mellitus                                                                           0.727627
# Alzheimer Disease                                                                           0.097544
# Influenza and Pneumonia                                                                     2.108072
# ...

# %% [markdown]
# ## Skewness
# Skewness is a measure of **asymmetry** in the distribution of a given set of data. A given variable can be classified as either:
# 1. **Symmetric:** The distribution of data is mirrored evenly along both sides of the median. Also known as *unskewed*.
# 2. **Negatively Skewed:** The distribution of data is heavier to the right side of the graph, with the left side tapering off in an elongated tail. Also known as *skewed to the left*.
# 3. **Positively Skewed:** The distribution of data is heavier to the left side of the graph, with the right side tapering off in an elongated tail. Also known as *skewed to the right*.
#
# ![](../images/skew.png)
#
# In cases where the degree of skewness is minute, visual inspection can be difficult to carry out. To make the process of identifying the skewness of a distribution easier, most statistical texts refer to the following *rule of thumb*:
# 1. If the distribution is **symmetric**, the mean is **equal to** the median.
# 2. If the distribution is **negatively skewed**, the mean is **less than** the median.
# 3. If the distribution is **positively skewed**, the mean is **greater than** the median.
#
# In this data, we can divided into two group:
#
# **Positively Skewed** = Natural Cause, Septicemia,Diabetes Mellitus, Alzheimer Disease, Influenza and Pneumonia,                   Chronic Lower Respiratory Diseases, Other Diseases of Respiratory System, Nephritis, Nephrotic Syndrome, and Nephrosis,
# Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified, Diseases of Heart, and Cerebrovascular Diseases.
#
# **Negatively Skewed** = Malignant Neoplasms, Accidents (Unintentional Injuries), Motor Vehicle Accidents, Intentional Self-Harm (Suicide), Assault (Homicide) and Drug Overdose.

# %%
death.kurtosis()
# Out:
# Year                                                                                       -1.273086
# Month                                                                                      -1.217513
# All Cause                                                                                   1.416787
# Natural Cause                                                                               1.372565
# Septicemia                                                                                  1.411311
# Malignant Neoplasms                                                                         0.079228
# Diabetes Mellitus                                                                           0.329456
# Alzheimer Disease                                                                           0.660186
# Influenza and Pneumonia                                                                     5.842711
# ...

# %% [markdown]
# ## Kurtosis
# Kurtosis is a measure of *tailedness*, i.e. how heavily the data is saturated in the tails of the distribution as opposed to its center. Visually, kurtosis manifests as either a *shorter* or *taller* distribution along the y-axis. This appearance is mainly due to the tails being *fatter* or *thinner* respectively.
#
# ![](../images/leptplat.png)
#
# Kurtosis uses the Normal distribution as a **point of reference**, i.e. it measures how much thinner/fatter the tails of a distribution are *compared to* a Normal distribution.
# 1. If the kurtosis is **negative** ($<0$), we say the distribution is **platykurtic**. This means its tails are **thinner** than that of a Normal distribution. Visually, platykurtic distributions appear **shorter** in height compared to a Normal distribution.
# 2. If the kurtosis value is **zero** ($=0$), we say the distribution is **mesokurtic**. This means the thickness of its tails are **identical**/**similar** to that of a Normal distribution.
# 3. If the kurtosis value is **positive** ($>0$), we say the distribution is **leptokurtic**. This means its tails are **thicker** than that of a Normal distribution. Visually, leptokurtic distributions appear **taller** in height compared to a Normal distribution.
#
# In this Data, we can group the column into 2 categories:
#
# **Platykutic** = Accidents (Unintentional Injuries), Intentional Self-Harm (Suicide), Drug Overdose.
#
# **mesokurtic** = Motor Vehicle Accidents,Malignant Neoplasms and Diabetes Mellitus.
#
# **leptokurtic** = Assault (Homicide), All Cause, Natural Cause, Septicemia, Diabetes Mellitus, Alzheimer Disease, Influenza and Pneumonia, Chronic Lower Respiratory Diseases, Other Diseases of Respiratory System, Nephritis, Nephrotic Syndrome, and Nephrosis, Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified, Diseases of Heart and Cerebrovascular Diseases.

# %%
death.describe()
# Out:
#              Year      Month      All Cause  Natural Cause   Septicemia  \
# count    72.00000  72.000000      72.000000      72.000000    72.000000
# mean   2016.50000   6.500000  230428.361111  211008.333333  3338.847222
# std       1.71981   3.476278   15602.341422   15118.931548   328.925466
# min    2014.00000   1.000000  204687.000000  187644.000000  2886.000000
# 25%    2015.00000   3.750000  219880.250000  199788.500000  3120.250000
# 50%    2016.50000   6.500000  227895.000000  208178.500000  3248.000000
# 75%    2018.00000   9.250000  237163.750000  216745.250000  3527.500000
# max    2019.00000  12.000000  286744.000000  265418.000000  4502.000000
#
#        Malignant Neoplasms  Diabetes Mellitus  Alzheimer Disease  \
# count            72.000000          72.000000          72.000000
# mean          49772.930556        6836.638889        9515.652778
# std            1543.032804         611.213600        1267.264717
# ...

# %%
#Heat Map of Correlations
corr_matrix = death.corr()
plt.figure(figsize = (12,7))
sns.heatmap(corr_matrix, cmap='PiYG', annot= True, square= False, fmt='.1g')
plt.title('Death Causes: Correlation between Numerical Columns');

# %%
sns.relplot(y="Diseases of Heart", x="Year", kind="line",ci = None, data=death)
plt.title("Diseases of Heart vs Year")
print("\n")
sns.relplot(y="Diseases of Heart", x="Month", kind="line",ci = None, data=death)
plt.title("Diseases of Heart vs Month")
print("\n")

# %%
from statistics import mode
from scipy.special import binom
from scipy.stats import iqr

# %%
print(f"""
The minimum is {min(death["Diseases of Heart"])}
The first quartile is {np.quantile(death["Diseases of Heart"],.25)}
The median is {np.median(death["Diseases of Heart"])}
The third quartile is {np.quantile(death["Diseases of Heart"],.75)}
The maximum is {max(death["Diseases of Heart"])}
The range is {max(death["Diseases of Heart"]) - min(death["Diseases of Heart"])}
The IQR is {iqr(death["Diseases of Heart"])}
The lower fence is {np.quantile(death["Diseases of Heart"],.25) - 1.5 * iqr(death["Diseases of Heart"])}
The upper fence is {np.quantile(death["Diseases of Heart"],.75) + 1.5 * iqr(death["Diseases of Heart"])}
""")

plt.boxplot(death["Diseases of Heart"])
# Out:
# The minimum is 46909
# The first quartile is 50367.0
# The median is 52765.0
# The third quartile is 54980.5
# The maximum is 67024
# The range is 20115
# The IQR is 4613.5
# The lower fence is 43446.75
# The upper fence is 61900.75
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5c04e8250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5c04e8ac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5c04c70d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5c04e8dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5c14dc130>],
#  'means': []}

# %%
sns.relplot(y="Septicemia", x="Year", kind="line",ci = None, data=death)
plt.title("Septicemia vs Year")
print("\n")
sns.relplot(y="Septicemia", x="Month", kind="line",ci = None, data=death)
plt.title("Septicemia vs Month")
# Out:
# Text(0.5, 1.0, 'Septicemia vs Month')

# %%
print(f"""
The minimum is {min(death["Septicemia"])}
The first quartile is {np.quantile(death["Septicemia"],.25)}
The median is {np.median(death["Septicemia"])}
The third quartile is {np.quantile(death["Septicemia"],.75)}
The maximum is {max(death["Septicemia"])}
The range is {max(death["Septicemia"]) - min(death["Septicemia"])}
The IQR is {iqr(death["Septicemia"])}
The lower fence is {np.quantile(death["Septicemia"],.25) - 1.5 * iqr(death["Septicemia"])}
The upper fence is {np.quantile(death["Septicemia"],.75) + 1.5 * iqr(death["Septicemia"])}
""")

plt.boxplot(death["Septicemia"])
# Out:
# The minimum is 2886
# The first quartile is 3120.25
# The median is 3248.0
# The third quartile is 3527.5
# The maximum is 4502
# The range is 1616
# The IQR is 407.25
# The lower fence is 2509.375
# The upper fence is 4138.375
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5c03988e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5c0398ca0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5c03983a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5c039fa00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5c039ff10>],
#  'means': []}

# %%
sns.relplot(y="Malignant Neoplasms", x="Year", kind="line",ci = None, data=death)
plt.title("Malignant Neoplasms vs Year")
print("\n")
sns.relplot(y="Malignant Neoplasms", x="Month", kind="line",ci = None, data=death)
plt.title("Septicemia vs Month")
# Out:
# Text(0.5, 1.0, 'Septicemia vs Month')

# %%
print(f"""
The minimum is {min(death["Malignant Neoplasms"])}
The first quartile is {np.quantile(death["Malignant Neoplasms"],.25)}
The median is {np.median(death["Malignant Neoplasms"])}
The third quartile is {np.quantile(death["Malignant Neoplasms"],.75)}
The maximum is {max(death["Malignant Neoplasms"])}
The range is {max(death["Malignant Neoplasms"]) - min(death["Malignant Neoplasms"])}
The IQR is {iqr(death["Malignant Neoplasms"])}
The lower fence is {np.quantile(death["Malignant Neoplasms"],.25) - 1.5 * iqr(death["Malignant Neoplasms"])}
The upper fence is {np.quantile(death["Malignant Neoplasms"],.75) + 1.5 * iqr(death["Malignant Neoplasms"])}
""")

plt.boxplot(death["Malignant Neoplasms"])
# Out:
# The minimum is 45558
# The first quartile is 48775.75
# The median is 49820.5
# The third quartile is 50880.75
# The maximum is 52876
# The range is 7318
# The IQR is 2105.0
# The lower fence is 45618.25
# The upper fence is 54038.25
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bcf4e7f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bcf4e310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bcf4e880>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bcf6a9a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bcf6a610>],
#  'means': []}

# %%
sns.relplot(y="Diabetes Mellitus", x="Year", kind="line",ci = None, data=death)
plt.title("Diabetes Mellitus vs Year")
print("\n")
sns.relplot(y="Diabetes Mellitus", x="Month", kind="line",ci = None, data=death)
plt.title("Diabetes Mellitus vs Month")
# Out:
# Text(0.5, 1.0, 'Diabetes Mellitus vs Month')

# %%
print(f"""
The minimum is {min(death["Diabetes Mellitus"])}
The first quartile is {np.quantile(death["Diabetes Mellitus"],.25)}
The median is {np.median(death["Diabetes Mellitus"])}
The third quartile is {np.quantile(death["Diabetes Mellitus"],.75)}
The maximum is {max(death["Diabetes Mellitus"])}
The range is {max(death["Diabetes Mellitus"]) - min(death["Diabetes Mellitus"])}
The IQR is {iqr(death["Diabetes Mellitus"])}
The lower fence is {np.quantile(death["Diabetes Mellitus"],.25) - 1.5 * iqr(death["Diabetes Mellitus"])}
The upper fence is {np.quantile(death["Diabetes Mellitus"],.75) + 1.5 * iqr(death["Diabetes Mellitus"])}
""")

plt.boxplot(death["Diabetes Mellitus"])
# Out:
# The minimum is 5802
# The first quartile is 6454.25
# The median is 6714.0
# The third quartile is 7154.75
# The maximum is 8674
# The range is 2872
# The IQR is 700.5
# The lower fence is 5403.5
# The upper fence is 8205.5
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bce78fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bce78790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bce78f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bc6b0910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bce6c4c0>],
#  'means': []}

# %%
sns.relplot(y="Alzheimer Disease", x="Year", kind="line",ci = None, data=death)
plt.title("Alzheimer Disease vs Year")
print("\n")
sns.relplot(y="Alzheimer Disease", x="Month", kind="line",ci = None, data=death)
plt.title("Alzheimer Disease vs Month")
# Out:
# Text(0.5, 1.0, 'Alzheimer Disease vs Month')

# %%
print(f"""
The minimum is {min(death["Alzheimer Disease"])}
The first quartile is {np.quantile(death["Alzheimer Disease"],.25)}
The median is {np.median(death["Alzheimer Disease"])}
The third quartile is {np.quantile(death["Alzheimer Disease"],.75)}
The maximum is {max(death["Alzheimer Disease"])}
The range is {max(death["Alzheimer Disease"]) - min(death["Alzheimer Disease"])}
The IQR is {iqr(death["Alzheimer Disease"])}
The lower fence is {np.quantile(death["Alzheimer Disease"],.25) - 1.5 * iqr(death["Alzheimer Disease"])}
The upper fence is {np.quantile(death["Alzheimer Disease"],.75) + 1.5 * iqr(death["Alzheimer Disease"])}
""")

plt.boxplot(death["Alzheimer Disease"])
# Out:
# The minimum is 6755
# The first quartile is 8933.75
# The median is 9419.0
# The third quartile is 10129.5
# The maximum is 13410
# The range is 6655
# The IQR is 1195.75
# The lower fence is 7140.125
# The upper fence is 11923.125
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bc2e4b20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bca359d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bc2e4250>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bca35820>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bca35d30>],
#  'means': []}

# %%
sns.relplot(y="Chronic Lower Respiratory Diseases", x="Year", kind="line",ci = None, data=death)
plt.title("Chronic Lower Respiratory Diseases vs Year")
print("\n")
sns.relplot(y="Chronic Lower Respiratory Diseases", x="Month", kind="line",ci = None, data=death)
plt.title("Chronic Lower Respiratory Diseases vs Month")
# Out:
# Text(0.5, 1.0, 'Chronic Lower Respiratory Diseases vs Month')

# %%
print(f"""
The minimum is {min(death["Chronic Lower Respiratory Diseases"])}
The first quartile is {np.quantile(death["Chronic Lower Respiratory Diseases"],.25)}
The median is {np.median(death["Chronic Lower Respiratory Diseases"])}
The third quartile is {np.quantile(death["Chronic Lower Respiratory Diseases"],.75)}
The maximum is {max(death["Chronic Lower Respiratory Diseases"])}
The range is {max(death["Chronic Lower Respiratory Diseases"]) - min(death["Chronic Lower Respiratory Diseases"])}
The IQR is {iqr(death["Chronic Lower Respiratory Diseases"])}
The lower fence is {np.quantile(death["Chronic Lower Respiratory Diseases"],.25) - 1.5 * iqr(death["Chronic Lower Respiratory Diseases"])}
The upper fence is {np.quantile(death["Chronic Lower Respiratory Diseases"],.75) + 1.5 * iqr(death["Chronic Lower Respiratory Diseases"])}
""")

plt.boxplot(death["Chronic Lower Respiratory Diseases"])
# Out:
# The minimum is 10426
# The first quartile is 11679.5
# The median is 12308.0
# The third quartile is 14033.5
# The maximum is 18271
# The range is 7845
# The IQR is 2354.0
# The lower fence is 8148.5
# The upper fence is 17564.5
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bc8507c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bc14cf40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bc5ed760>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bc14ceb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bc14c070>],
#  'means': []}

# %%
sns.relplot(y="Nephritis, Nephrotic Syndrome, and Nephrosis", x="Year", kind="line",ci = None, data=death)
plt.title("Nephritis, Nephrotic Syndrome, and Nephrosis vs Year")
print("\n")
sns.relplot(y="Nephritis, Nephrotic Syndrome, and Nephrosis", x="Month", kind="line",ci = None, data=death)
plt.title("Nephritis, Nephrotic Syndrome, and Nephrosis  vs Month")
# Out:
# Text(0.5, 1.0, 'Nephritis, Nephrotic Syndrome, and Nephrosis  vs Month')

# %%
print(f"""
The minimum is {min(death["Nephritis, Nephrotic Syndrome, and Nephrosis"])}
The first quartile is {np.quantile(death["Nephritis, Nephrotic Syndrome, and Nephrosis"],.25)}
The median is {np.median(death["Nephritis, Nephrotic Syndrome, and Nephrosis"])}
The third quartile is {np.quantile(death["Nephritis, Nephrotic Syndrome, and Nephrosis"],.75)}
The maximum is {max(death["Nephritis, Nephrotic Syndrome, and Nephrosis"])}
The range is {max(death["Nephritis, Nephrotic Syndrome, and Nephrosis"]) - min(death["Nephritis, Nephrotic Syndrome, and Nephrosis"])}
The IQR is {iqr(death["Nephritis, Nephrotic Syndrome, and Nephrosis"])}
The lower fence is {np.quantile(death["Nephritis, Nephrotic Syndrome, and Nephrosis"],.25) - 1.5 * iqr(death["Nephritis, Nephrotic Syndrome, and Nephrosis"])}
The upper fence is {np.quantile(death["Nephritis, Nephrotic Syndrome, and Nephrosis"],.75) + 1.5 * iqr(death["Nephritis, Nephrotic Syndrome, and Nephrosis"])}
""")

plt.boxplot(death["Nephritis, Nephrotic Syndrome, and Nephrosis"])
# Out:
# The minimum is 3631
# The first quartile is 3925.75
# The median is 4110.5
# The third quartile is 4373.25
# The maximum is 5346
# The range is 1715
# The IQR is 447.5
# The lower fence is 3254.5
# The upper fence is 5044.5
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bc1813d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bc213550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bc1816a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bc2136a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bc197a30>],
#  'means': []}

# %%
sns.relplot(y="Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified", x="Year", kind="line",ci = None, data=death)
plt.title("Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified vs Year")
print("\n")
sns.relplot(y="Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified", x="Month", kind="line",ci = None, data=death)
plt.title("Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified vs Month")
# Out:
# Text(0.5, 1.0, 'Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified vs Month')

# %%
print(f"""
The minimum is {min(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"])}
The first quartile is {np.quantile(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"],.25)}
The median is {np.median(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"])}
The third quartile is {np.quantile(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"],.75)}
The maximum is {max(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"])}
The range is {max(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"]) - min(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"])}
The IQR is {iqr(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"])}
The lower fence is {np.quantile(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"],.25) - 1.5 * iqr(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"])}
The upper fence is {np.quantile(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"],.75) + 1.5 * iqr(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"])}
""")

plt.boxplot(death["Symptoms, Signs, and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified"])
# Out:
# The minimum is 2449
# The first quartile is 2551.0
# The median is 2633.5
# The third quartile is 2812.0
# The maximum is 3465
# The range is 1016
# The IQR is 261.0
# The lower fence is 2159.5
# The upper fence is 3203.5
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bc5d3610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bc532e80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bc5d31f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bc6cc100>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bc6cc0a0>],
#  'means': []}

# %%
sns.relplot(y="Cerebrovascular Diseases", x="Year", kind="line",ci = None, data=death)
plt.title("Cerebrovascular Diseases vs Year")
print("\n")
sns.relplot(y="Cerebrovascular Diseases", x="Month", kind="line",ci = None, data=death)
plt.title("Cerebrovascular Diseases vs Month")
# Out:
# Text(0.5, 1.0, 'Cerebrovascular Diseases vs Month')

# %%
print(f"""
The minimum is {min(death["Cerebrovascular Diseases"])}
The first quartile is {np.quantile(death["Cerebrovascular Diseases"],.25)}
The median is {np.median(death["Cerebrovascular Diseases"])}
The third quartile is {np.quantile(death["Cerebrovascular Diseases"],.75)}
The maximum is {max(death["Cerebrovascular Diseases"])}
The range is {max(death["Cerebrovascular Diseases"]) - min(death["Cerebrovascular Diseases"])}
The IQR is {iqr(death["Cerebrovascular Diseases"])}
The lower fence is {np.quantile(death["Cerebrovascular Diseases"],.25) - 1.5 * iqr(death["Cerebrovascular Diseases"])}
The upper fence is {np.quantile(death["Cerebrovascular Diseases"],.75) + 1.5 * iqr(death["Cerebrovascular Diseases"])}
""")

plt.boxplot(death["Cerebrovascular Diseases"])
# Out:
# The minimum is 9973
# The first quartile is 11337.5
# The median is 11814.0
# The third quartile is 12428.0
# The maximum is 14653
# The range is 4680
# The IQR is 1090.5
# The lower fence is 9701.75
# The upper fence is 14063.75
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bc9d1bb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bc9d1310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bc696be0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bc55cf40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bc55c1c0>],
#  'means': []}

# %%
sns.relplot(y="Accidents (Unintentional Injuries)", x="Year", kind="line",ci = None, data=death)
plt.title("Accidents (Unintentional Injuries) vs Year")
print("\n")
sns.relplot(y="Accidents (Unintentional Injuries)", x="Month", kind="line",ci = None, data=death)
plt.title("Accidents (Unintentional Injuries) vs Month")
# Out:
# Text(0.5, 1.0, 'Accidents (Unintentional Injuries) vs Month')

# %%
print(f"""
The minimum is {min(death["Accidents (Unintentional Injuries)"])}
The first quartile is {np.quantile(death["Accidents (Unintentional Injuries)"],.25)}
The median is {np.median(death["Accidents (Unintentional Injuries)"])}
The third quartile is {np.quantile(death["Accidents (Unintentional Injuries)"],.75)}
The maximum is {max(death["Accidents (Unintentional Injuries)"])}
The range is {max(death["Accidents (Unintentional Injuries)"]) - min(death["Accidents (Unintentional Injuries)"])}
The IQR is {iqr(death["Accidents (Unintentional Injuries)"])}
The lower fence is {np.quantile(death["Accidents (Unintentional Injuries)"],.25) - 1.5 * iqr(death["Accidents (Unintentional Injuries)"])}
The upper fence is {np.quantile(death["Accidents (Unintentional Injuries)"],.75) + 1.5 * iqr(death["Accidents (Unintentional Injuries)"])}
""")

plt.boxplot(death["Accidents (Unintentional Injuries)"])
# Out:
# The minimum is 10286
# The first quartile is 12306.5
# The median is 13488.0
# The third quartile is 14225.5
# The maximum is 15292
# The range is 5006
# The IQR is 1919.0
# The lower fence is 9428.0
# The upper fence is 17104.0
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bc589880>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bc708d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bc589700>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bc4543a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bc4547f0>],
#  'means': []}

# %%
sns.relplot(y="Intentional Self-Harm (Suicide)", x="Year", kind="line",ci = None, data=death)
plt.title("Intentional Self-Harm (Suicide) vs Year")
print("\n")
sns.relplot(y="Intentional Self-Harm (Suicide)", x="Month", kind="line",ci = None, data=death)
plt.title("Intentional Self-Harm (Suicide) vs Month")
# Out:
# Text(0.5, 1.0, 'Intentional Self-Harm (Suicide) vs Month')

# %%
print(f"""
The minimum is {min(death["Intentional Self-Harm (Suicide)"])}
The first quartile is {np.quantile(death["Intentional Self-Harm (Suicide)"],.25)}
The median is {np.median(death["Intentional Self-Harm (Suicide)"])}
The third quartile is {np.quantile(death["Intentional Self-Harm (Suicide)"],.75)}
The maximum is {max(death["Intentional Self-Harm (Suicide)"])}
The range is {max(death["Intentional Self-Harm (Suicide)"]) - min(death["Intentional Self-Harm (Suicide)"])}
The IQR is {iqr(death["Intentional Self-Harm (Suicide)"])}
The lower fence is {np.quantile(death["Intentional Self-Harm (Suicide)"],.25) - 1.5 * iqr(death["Intentional Self-Harm (Suicide)"])}
The upper fence is {np.quantile(death["Intentional Self-Harm (Suicide)"],.75) + 1.5 * iqr(death["Intentional Self-Harm (Suicide)"])}
""")

plt.boxplot(death["Intentional Self-Harm (Suicide)"])
# Out:
# The minimum is 3091
# The first quartile is 3596.75
# The median is 3835.5
# The third quartile is 4042.25
# The maximum is 4378
# The range is 1287
# The IQR is 445.5
# The lower fence is 2928.5
# The upper fence is 4710.5
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bcf37700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bcf37ca0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bcf37430>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bcdeb280>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bcdeb550>],
#  'means': []}

# %%
sns.relplot(y="Assault (Homicide)", x="Year", kind="line",ci = None, data=death)
plt.title("Assault (Homicide) vs Year")
print("\n")
sns.relplot(y="Assault (Homicide)", x="Month", kind="line",ci = None, data=death)
plt.title("Assault (Homicide) vs Month")
# Out:
# Text(0.5, 1.0, 'Assault (Homicide) vs Month')

# %%
print(f"""
The minimum is {min(death["Assault (Homicide)"])}
The first quartile is {np.quantile(death["Assault (Homicide)"],.25)}
The median is {np.median(death["Assault (Homicide)"])}
The third quartile is {np.quantile(death["Assault (Homicide)"],.75)}
The maximum is {max(death["Assault (Homicide)"])}
The range is {max(death["Assault (Homicide)"]) - min(death["Assault (Homicide)"])}
The IQR is {iqr(death["Assault (Homicide)"])}
The lower fence is {np.quantile(death["Assault (Homicide)"],.25) - 1.5 * iqr(death["Assault (Homicide)"])}
The upper fence is {np.quantile(death["Assault (Homicide)"],.75) + 1.5 * iqr(death["Assault (Homicide)"])}
""")

plt.boxplot(death["Assault (Homicide)"])
# Out:
# The minimum is 1050
# The first quartile is 1434.75
# The median is 1563.5
# The third quartile is 1658.25
# The maximum is 1804
# The range is 754
# The IQR is 223.5
# The lower fence is 1099.5
# The upper fence is 1993.5
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5c15a5d00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5c15b72e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5c15a5a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5c15b7880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5c15b7b50>],
#  'means': []}

# %%
sns.relplot(y="Drug Overdose", x="Year", kind="line",ci = None, data=death)
plt.title("Drug Overdose vs Year")
print("\n")
sns.relplot(y="Drug Overdose", x="Month", kind="line",ci = None, data=death)
plt.title("Drug Overdose vs Month")
# Out:
# Text(0.5, 1.0, 'Drug Overdose vs Month')

# %%
print(f"""
The minimum is {min(death["Drug Overdose"])}
The first quartile is {np.quantile(death["Drug Overdose"],.25)}
The median is {np.median(death["Drug Overdose"])}
The third quartile is {np.quantile(death["Drug Overdose"],.75)}
The maximum is {max(death["Drug Overdose"])}
The range is {max(death["Drug Overdose"]) - min(death["Drug Overdose"])}
The IQR is {iqr(death["Drug Overdose"])}
The lower fence is {np.quantile(death["Drug Overdose"],.25) - 1.5 * iqr(death["Drug Overdose"])}
The upper fence is {np.quantile(death["Drug Overdose"],.75) + 1.5 * iqr(death["Drug Overdose"])}
""")

plt.boxplot(death["Drug Overdose"])
# Out:
# The minimum is 3733
# The first quartile is 4435.0
# The median is 5477.5
# The third quartile is 5820.0
# The maximum is 6299
# The range is 2566
# The IQR is 1385.0
# The lower fence is 2357.5
# The upper fence is 7897.5
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5bcd46a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f5bcd55070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5bcd467c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f5bcd55610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f5bcd558e0>],
#  'means': []}

# %% [markdown]
# **What do I want to show the audience?**
# People most likely will get sick or desease during the Winter season which is between December until March
#
# **What is the context**
# Colds, flus and other respiratory illnesses are more common in colder months. This is partly due to the fact that cold and flu viruses are more prevalent in the colder months, and people are also more likely to spend time indoors in close proximity to others, which can facilitate the spread of infections. Additionally, the dry winter air can dry out the mucous membranes in the nose and throat, making it easier for viruses to take hold.
#
# The data show the respiratory rellated deseases like Cerebrovascular Diseases, Malignant Neoplasms, Septimecia, Deseases of heart, (Nephritis, Nephrotic Syndrome, and Nephrosis), Chronic Lower Respiratory Diseases show the number higher during winter season (December to March) compare to other season.
#
# **Do I have a call-to-action?**
# People is encouraged to get flu shot/vaccine, exercise regularly, eat healthy and keep good hygience.

# %%
class test:
    def__init__(self):
    self.x=0
class Derived_Test(Test):
    def__init__(self):
    self.y=1

def main():
    b = Derived_test()
    print(b.x,b.y)

main()
# Out:
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_14004\3676145800.py", line 2
#     def__init__(self):
#                       ^
# SyntaxError: invalid syntax
